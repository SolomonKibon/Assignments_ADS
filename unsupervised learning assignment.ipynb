# %%
import pandas as pd
# Load the dataset
data = pd.read_csv("data/CC GENERAL.csv")

data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
#drop unnecessary columns
data = data.drop(["CUST_ID"], axis=1)  # Drop unnecessary columns
data.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#check for missing values
data.isnull().sum()
# Out:
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
#fill null values
data=data.fillna(data.median())
data.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#apply feature scaling
# Standardize the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
#Apply the K-means clustering algorithm for customer segmentation:
#Determine the optimal number of clusters using the elbow method or silhouette score
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
silhouette_scores = []
for n_clusters in range(2, 11):
    kmeans = KMeans(n_clusters=n_clusters,n_init=1, random_state=42)
    cluster_labels = kmeans.fit_predict(scaled_data)
    silhouette_scores.append(silhouette_score(scaled_data, cluster_labels))

optimal_clusters = silhouette_scores.index(max(silhouette_scores)) + 2
print("Optimal number of clusters:", optimal_clusters)
# Out:
# Optimal number of clusters: 10

# %%
# Initialize the KMeans model
kmeans = KMeans(n_clusters=optimal_clusters,n_init=1, random_state=42)

# Fit the model and make predictions
cluster_assignments = kmeans.fit_predict(scaled_data)

# %%
# Add the cluster labels to the original dataset
data['Cluster'] = cluster_assignments
data.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
# Step 3: Visualize and Analyze the Results
# Visualize the clusters using two features (eg BALANCE AND PURCHASE)
# Add the cluster labels to the original dataset
data['Cluster'] = cluster_assignments

# Visualize using seaborn scatterplot
import seaborn as sns
sns.scatterplot(x='BALANCE', y='PURCHASES', data=data, hue='Cluster', palette='viridis')
plt.title('Cluster Visualization')
plt.xlabel('Balance')
plt.ylabel('Purchases')
plt.show()

# %%
# Analyze cluster characteristics
cluster_stats = data.groupby('Cluster').mean()
print(cluster_stats)
# Out:
#              BALANCE  BALANCE_FREQUENCY    PURCHASES  ONEOFF_PURCHASES  \
# Cluster
# 0         799.750669           0.835077   505.532394        253.120131
# 1        3989.142419           0.958403   384.528277        248.718133
# 2        2220.003291           0.981477  4268.520980       2717.828543
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# Cluster
# 0                    252.733061    330.817885             0.465072
# 1                    135.887632   3866.210340             0.232290
# 2                   1551.178267    458.421147             0.949093
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# Cluster
# 0                          0.132333                          0.345145
# 1                          0.110942                          0.144242
# 2                          0.668166                          0.744584
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# Cluster
# ...

# %% [markdown]
# Cluster 0:
#
#     Customers in this cluster have a moderate balance and balance frequency, indicating that they are relatively consistent in maintaining their balances.
#     Their average purchase amount is lower compared to other clusters, suggesting they might be cautious spenders.
#     Business Implications: Target these customers with promotions or rewards that encourage more frequent purchases. Offer them deals on low-cost items or services to increase their spending frequency.
#
# Cluster 1:
#
#     Customers in this cluster have significantly higher balances and balance frequency compared to other clusters.
#     Their average purchase amount is relatively low, which could indicate that they are not making the most of their available balance.
#     Business Implications: This cluster could be an opportunity for premium services or products. Offer them exclusive rewards or personalized recommendations to encourage higher-value purchases.
#
# Cluster 2:
#
#     Customers in this cluster have a moderately high balance and balance frequency.
#     Their purchases are considerably higher, especially for one-off purchases.
#     Business Implications: Recognize that these customers are likely to make significant one-off purchases. Tailor marketing campaigns to highlight special offers, limited-time deals, or exclusive products to encourage more of these high-value transactions.
